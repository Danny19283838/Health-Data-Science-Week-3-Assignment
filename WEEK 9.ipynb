# %%
url =  "https://raw.githubusercontent.com/juanklopper/TutorialData/refs/heads/main/ICU_Mortality.csv"

# %%
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv(url)

# %%
# verify the size of 'df'
df.shape
# Out:
# (311, 6)

# %%
#Show the column headers
df.columns
# Out:
# Index(['Mortality', 'Age', 'WCC', 'HB', 'Diabetes', 'Class'], dtype='object')

# %%
# Show the first 5 rows of the dataframe
df.head()
# Out:
#   Mortality  Age   WCC    HB Diabetes           Class
# 0      Died   69  12.0  11.7      NaN  Non-infectious
# 1      Died   73   9.0  13.2      NaN  Non-infectious
# 2      Died   53  16.4  11.1      NaN  Non-infectious
# 3      Died   74  10.1  11.2  Type II      Infectious
# 4      Died   69  10.2  15.0   Type I      Infectious

# %%
#show info about 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Mortality  311 non-null    object
#  1   Age        311 non-null    int64
#  2   WCC        311 non-null    float64
#  3   HB         311 non-null    float64
#  4   Diabetes   213 non-null    object
#  5   Class      311 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 14.7+ KB

# %% [markdown]
# CATEGORICAL DATA

# %%
## Show the first 10 rows of the "Mortality" column
df['Mortality'].head(10)
# Out:
# 0    Died
# 1    Died
# 2    Died
# 3    Died
# 4    Died
# 5    Died
# 6    Died
# 7    Died
# 8    Died
# 9    Died
# Name: Mortality, dtype: object

# %%
#calculate the distinct values of the "mortality" column
df['Mortality'].value_counts()
# Out:
# Mortality
# Survived    207
# Died        104
# Name: count, dtype: int64

# %%
#Calculate the frequency of each category in the "Mortality" column
df.Mortality.value_counts()
# Out:
# Mortality
# Survived    207
# Died        104
# Name: count, dtype: int64

# %%
#Calculate the proportion of each category in the "Mortality" column
df.Mortality.value_counts(normalize=True)
# Out:
# Mortality
# Survived    0.665595
# Died        0.334405
# Name: proportion, dtype: float64

# %%
#Calculate the percentage of each category in the "Mortality" column
df.Mortality.value_counts(normalize=True) * 100
# Out:
# Mortality
# Survived    66.559486
# Died        33.440514
# Name: proportion, dtype: float64

# %%
#Calculate the percentage of each category in the "Class" column
df.Class.value_counts(normalize=True) * 100
# Out:
# Class
# Non-infectious    51.768489
# Infectious        48.231511
# Name: proportion, dtype: float64

# %%
#Create a cross-tabulation of the "Class" and "Class" columns
pd.crosstab(df.Class, df.Mortality)
# Out:
# Mortality       Died  Survived
# Class
# Infectious        49       101
# Non-infectious    55       106

# %% [markdown]
# Comparative numerical analysis

# %%
# Calcualte the mean of the "Age" column for each of the "Mortality" categories
df.groupby('Mortality')['Age'].mean()
# Out:
# Mortality
# Died        61.125000
# Survived    54.111111
# Name: Age, dtype: float64

# %% [markdown]
# Numerical Data Analysis

# %%
#Calculate the mean of the "Age" column
df['Age'].mean()
# Out:
# np.float64(56.456591639871384)

# %%
#Calculate the sample standard deviation of the "Age" column
df['Age'].std()
# Out:
# np.float64(10.974334278749502)

# %%
#Describe the summary statistics of the "age" column
df['Age'].describe()
# Out:
# count    311.000000
# mean      56.456592
# std       10.974334
# min       23.000000
# 25%       49.000000
# 50%       56.000000
# 75%       64.000000
# max       85.000000
# Name: Age, dtype: float64

# %%
#Describe the summary statistics of the "age" column for each category of the "Mortality" column
df.groupby('Mortality')['Age'].describe()
# Out:
#            count       mean        std   min    25%   50%   75%   max
# Mortality
# Died       104.0  61.125000   9.738012  45.0  52.75  61.0  69.0  77.0
# Survived   207.0  54.111111  10.830209  23.0  47.00  53.0  60.0  85.0

# %%
#Calculate the correlation between the "Age" and "WCC" columns
df.Age.corr(df.WCC)
# Out:
# np.float64(-0.002851239185865934)

# %% [markdown]
# DATA VISUALIZATION WEEK 9 CLASSWORK

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Verify seaborn installation
print(f"Seaborn version: {sns.__version__}")
# Out:
# Seaborn version: 0.13.2

# %%
url =  "https://raw.githubusercontent.com/juanklopper/TutorialData/main/heart_failure.csv"

# %%
df = pd.read_csv(url)

# %%
print(df.columns)
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'hypertension', 'platelets', 'serum_creatinine',
#        'serum_sodium', 'sex', 'smoking', 'time', 'death'],
#       dtype='object')

# %%
# Verify seaborn is imported correctly
print(f"Seaborn version: {sns.__version__}")
# Out:
# Seaborn version: 0.13.2

# %% [markdown]
# SCATTERPLOTS

# %%
sns.scatterplot(
    data=df,
    x='age',
    y='platelets'
)
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
sns.scatterplot(
    data=df,
    x='age',
    y='platelets',
    hue='anaemia',
    style='anaemia'
).set(
    title='Age and Platelets',
    xlabel='Age [years]',
    ylabel='Platelets [platelets/mL]'
)
# Out:
# [Text(0.5, 1.0, 'Age and Platelets'),
#  Text(0.5, 0, 'Age [years]'),
#  Text(0, 0.5, 'Platelets [platelets/mL]')]

# %%
sns.scatterplot(
    data=df,
    x='platelets',
    y='serum_sodium',
    hue='diabetes'
).set(
    title='Platelets and serum sodium',
    xlabel='Platelets [platelets/mL]',
    ylabel='Serum sodium [mEq/L]'
)
# Out:
# [Text(0.5, 1.0, 'Platelets and serum sodium'),
#  Text(0.5, 0, 'Platelets [platelets/mL]'),
#  Text(0, 0.5, 'Serum sodium [mEq/L]')]

# %%
sns.scatterplot(
    data=df,
    x='age',
    y='platelets',
    hue='serum_sodium'
).set(
    title='Age and Platelets',
    xlabel='Age [years]',
    ylabel='Platelets [platelets/mL]'
)

pyplot.legend(
    title='Serum sodium [mEq/L]',
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 12
#       1 sns.scatterplot(
#       2     data=df,
#       3     x='age',
#    (...)      9     ylabel='Platelets [platelets/mL]'
#      10 )
# ---> 12 pyplot.legend(
#      13     title='Serum sodium [mEq/L]',
#      14 )
#
# NameError: name 'pyplot' is not defined

# %%
sns.scatterplot(
    data=df,
    x='age',
    y='platelets',
    size='serum_sodium'
).set(
    title='Age and Platelets',
    xlabel='Age [years]',
    ylabel='Platelets [platelets/mL]'
)

pyplot.legend(
    title='Serum sodium [mEq/L]'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 12
#       1 sns.scatterplot(
#       2     data=df,
#       3     x='age',
#    (...)      9     ylabel='Platelets [platelets/mL]'
#      10 )
# ---> 12 pyplot.legend(
#      13     title='Serum sodium [mEq/L]'
#      14 )
#
# NameError: name 'pyplot' is not defined

# %%
sns.displot(
    df,
    x='age'
).set(
    title='Age distribution',
    xlabel='Age [years]',
    ylabel='Frequency'
)

# %%
sns.displot(
    df,
    x='age',
    bins=range(40, 110, 10)
).set(
    title='Age distribution',
    xlabel='Age [years]',
    ylabel='Frequency'
)

# %%
df.platelets.min()

df.platelets.max()

sns.displot(
    df,
    y='platelets',
    bins=range(0, 850000,50000)
).set(
    title='Platelet distribution',
    ylabel='Platelets [platelets/mL]',
    xlabel='Frequency'
)

# %%
sns.displot(
    df,
    x='age',
    bins=range(40, 110, 10),
    hue='anaemia'
).set(
    title='Age distribution',
    xlabel='Age [years]',
    ylabel='Frequency'
)

pyplot.legend(
    title='Anemia'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 12
#       1 sns.displot(
#       2     df,
#       3     x='age',
#    (...)      9     ylabel='Frequency'
#      10 )
# ---> 12 pyplot.legend(
#      13     title='Anemia'
#      14 )
#
# NameError: name 'pyplot' is not defined

# %%
sns.displot(
    df,
    x='age',
    bins=range(40, 110, 10),
    col='anaemia'
)

# %%
sns.displot(
    df,
    x='age',
    bins=range(40, 110, 10),
    col='anaemia',
    stat='probability'
)

# %%
sns.displot(
    df,
    x='age',
    y='platelets',
    cbar=True
).set(
    title='Age and Platelets',
    xlabel='Age [years]',
    ylabel='Platelets [platelets/mL]'
)

# %%
sns.displot(
    df,
    x='age',
    y='platelets',
    kind='kde',
    rug=True
).set(
    title='Age and Platelets',
    xlabel='Age [years]',
    ylabel='Platelets [platelets/mL]'
)

# %%
sns.jointplot(
    df,
    x='age',
    y='platelets'
)

# %%
g = sns.JointGrid(
    data=df,
    x='age',
    y='platelets'
)
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    kind='box'
).set(
    title='Age and Diabetes',
    xlabel='Diabetes',
    ylabel='Age [years]'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    hue='death',
    kind='box'
).set(
    title='Age and Diabetes by Survival Group',
    xlabel='Diabetes',
    ylabel='Age [years]'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    hue='death',
    kind='boxen'
).set(
    title='Age and Diabetes by Survival Group',
    xlabel='Diabetes',
    ylabel='Age [years]'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    hue='death',
    kind='violin'
).set(
    title='Age and Diabetes by Survival Group',
    xlabel='Diabetes',
    ylabel='Age [years]'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    hue='death',
    kind='violin',
    split=True
).set(
    title='Age and Diabetes by Survival Group',
    xlabel='Diabetes',
    ylabel='Age [years]'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    kind='swarm'
).set(
    title='Age and Diabetes',
    xlabel='Diabetes',
    ylabel='Age [years]'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    kind='count'
).set(
    title='Diabetes',
    xlabel='Diabetes',
    ylabel='Frequency'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    hue='death',
    kind='count'
)

# %%
sns.catplot(
    data=df,
    x='diabetes',
    y='age',
    hue='death',
    kind='point'
).set(
    title='Age',
    xlabel='Diabetes',
    ylabel='Age'
)

# %% [markdown]
# DATA VISUALIZATION WEEK 9 QUIZ QUESTIONS

# %% [markdown]
# Import Seaborn: import seaborn as sns
#
# Scatter plot: sns.scatterplot(data=df, x='x', y='y')
#
# Line plot: sns.lineplot(data=df, x='x', y='y')
#
# Histogram: sns.histplot(data=df, x='x')
#
# Stacked histogram: sns.histplot(data=df, x='x', hue='y', multiple='stack')
#
# Heatmap: sns.heatmap(data=df.pivot('x', 'y'))
#
# Box plot: sns.boxplot(data=df, x='x', y='y')
#
# Violin plot: sns.violinplot(data=df, x='x', y='y')
#
# Bar plot: sns.barplot(data=df, x='x', y='y')
#
# Add title: ax.set_title('My Title')
#
# Save plot: ax.figure.savefig('output.png')
#
# Set axis labels: ax.set(xlabel='X Label', ylabel='Y Label')
#
# Change color palette: sns.set_palette('Blues')
#
# Logarithmic y-axis: ax.set_yscale('log')
#
# Add regression line: sns.lmplot(data=df, x='x', y='y')
